# %%
import pandas as pd
import numpy as np
from numpy import newaxis
import matplotlib.pyplot as plt
import random
import seaborn as sns
import itertools
import os
from PIL import Image
import math
from matplotlib import gridspec
import matplotlib.collections
from glob import glob
from keras.applications import *
import lightgbm as lgbm
import scipy
import tensorflow


from matplotlib.transforms import Affine2D
import mpl_toolkits.axisartist.floating_axes as floating_axes
import matplotlib.collections

from sklearn.model_selection import *

from tqdm import *

import astrohack
from astrohack import *
# nice progress bars otherwise
# def tqdm(x):
#     yield x
# Out:
# Using TensorFlow backend.

# %%
df =  pd.read_csv('metadata_full.csv', sep = '\t')
df = df[df.ML_g < 25]
df.ML_g_rel_err = df.ML_g_rel_err.apply(np.float64)
df2 = pd.read_csv('metadata_refit_valid.csv', sep='\t')
# Out:
# /opt/anaconda3/envs/astrohack/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['SDSS_ID', 'RA', 'DEC', 'D25', 'redshift', 'logMstar', 'err_logMstar',
#        'GalSize_kpc', 'D_Mpc', 'd_pix_kpc', 'ML_g', 'ML_i', 'ML_g_rel_err',
#        'ML_i_rel_err', 'RA_leda', 'DEC_leda', 'D25_leda', 'R25_leda',
#        'pa_leda', 'petroMag_g', 'petroMagErr_g', 'petroMag_i', 'petroMagErr_i',
#        'ML_g_zibetti', 'hasimg', 'isgalaxy'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['SDSS_ID', 'RA', 'DEC', 'D25', 'redshift', 'GalSize_kpc', 'D_Mpc',
#        'd_pix_kpc', 'reduced_chi_square', 'logM_bayes', 'logM_bayes_err',
#        'L_g_bayes', 'L_g_bayes_err', 'hasimg', 'isgalaxy', 'M_bayes',
#        'M_bayes_err', 'ML_bayes', 'ML_bayes_err', 'mag_g', 'mag_i',
#        'ML_zibetti'],
#       dtype='object')

# %%
df2.plot(kind='scatter', x='L_g_bayes', y='L_g_bayes_err', figsize=(8,8) )
# plt.xscale('log')
# plt.yscale('log')
plt.show()

# %%
plt.plot(df2.logM_bayes)

df2.plot(kind='scatter', x='logM_bayes', y='logM_bayes_err', figsize=(12,12))

# %%
combined = pd.merge(df[['SDSS_ID', 'ML_g', 'ML_g_rel_err']], df2[['SDSS_ID', 'ML_bayes', 'ML_bayes_err']], how='left').dropna()

# %%
combined.columns
# Out:
# Index(['SDSS_ID', 'ML_g', 'ML_g_rel_err', 'ML_bayes', 'ML_bayes_err'], dtype='object')

# %%
combined.columns = ['SDSS_ID', 'ML_old', 'err_old', 'ML_new', 'err_new']

# %%
plt.figure(figsize=(6,12))
plt.subplot(211)
combined.ML_old.plot(kind='hist', bins=1000)
plt.title('old')
plt.subplot(212)
combined.ML_new.plot(kind='hist', bins=1000)
plt.title('new')

# %%
plt.show()
plt.ion()

# %%
combined.plot(kind='scatter', x='ML_old', y='ML_new',figsize=(12,12), alpha=0.3)

# %%
combined.plot(kind='scatter', x='err_old', y='err_new',figsize=(5,5))

# %%
combined[combined.err_old > 100].plot(kind='scatter',  x='ML_old', y='err_old')
combined[combined.err_old > 100].plot(kind='scatter',  x='ML_new', y='err_new')

# %%
combined[combined.err_old < 10].plot(kind='scatter', x='err_old', y='err_new')

# %%
plt.figure(figsize=(8,8))
plt.subplot(211)
plt.scatter(combined[combined.err_old < 10].ML_old, combined[combined.err_old < 10].err_old)
plt.ylabel('error')
plt.xlabel('ML')
plt.title('Old')
plt.subplot(212)
plt.scatter(combined[combined.err_old < 100].ML_new, combined[combined.err_old < 100].err_new)
plt.ylabel('error')
plt.xlabel('ML')
plt.title('New')

# %%
plt.figure(figsize=(8,8))
plt.subplot(211)
plt.hist(combined[combined.err_old < 1].err_old, bins=100)
plt.title('Old')
plt.subplot(212)
plt.hist(combined[combined.err_new < 1].err_new, bins=100)
plt.title('New')

# %%
plt.figure(figsize=(12,12))
plt.hist(combined[combined.err_old < 2].err_old, bins=1000)
1
# Out:
# 1

# %%
combined[combined.err_old < 100].plot(kind='scatter',  x='ML_old', y='err_old')
combined[combined.err_old < 100].plot(kind='scatter',  x='ML_new', y='err_new')

# %%
combined['err_new_sq'] = combined.err_new.apply(lambda x: 1/x**2)
combined['err_old_sq'] = combined.err_old.apply(lambda x: 1/x**2)

# %%
combined.plot(kind='scatter', x='ML_new', y='err_new_sq')
combined.plot(kind='scatter', x='ML_old', y='err_old_sq')

# %%
combined[combined.err_new < 1].err_new.hist(bins=100)

# %%
combined[combined.err_old < 1].err_old.hist(bins=100)

# %%
combined['new_errratio'] = combined.err_new/combined.ML_new
combined['old_errratio'] = combined.err_old/combined.ML_old

# %%
combined[combined.err_old < 1].plot(kind='scatter',x='ML_old', y='old_errratio')
combined.plot(kind='scatter',x='ML_new', y='new_errratio')
# combined.plot()
